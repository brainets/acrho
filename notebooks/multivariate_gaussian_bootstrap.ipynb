# %% [markdown]
# # Analysis of HOIs generated with a simple operation as multiplication or copy

# %% [markdown]
# In the following lines we reproduce a simple scenario in which we have 6 features, 3 of them presenting some interdependencies with a target and 3 of them independent from the target. For instance in the case presented in this notebook, we have:
#
#  - a redundant/synergistic interaction between variables 0,1,2 and the target;
#
#  - a synergystic/redundant interaction within the multiplet of variables 3,4,5 that is independent from the target.
#
#  We also generate the evolution of this interdependencies on a third dimension, following the shape of an hanning window.

# %% [markdown]
# # Not very significant

# %%
import numpy as np
from numpy import random
import hoi
import matplotlib.pyplot as plt

from frites.utils import parallel_func


from utils import oinfo_min, goinfo_create_fit, goinfo_create_fit_correction, bootstrap

# %%
#the target variable can be multivariate
target = random.multivariate_normal([0,0],[[1,0],[0,1]], 300).T
n_samples = 4000
n_features = 4

data = np.zeros((n_features, n_samples))

data[0] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[1] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[2] =  random.normal(loc=0.0, scale=1.0, size=n_samples)

data[3]=data[2]+data[1]+0.3*data[0]+ 0.5*random.normal(loc=0.0, scale=1.0, size=n_samples)

data_boot=bootstrap(data.T)

# %% [markdown]
# How to compute HOIs ?

# %%
# Here we define min and max order that we want to compute

minsize=2
maxsize=4

#Here we create a 
model = hoi.metrics.Oinfo(data_boot)
oinfo = model.fit(minsize=minsize, maxsize=maxsize)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]

# %% [markdown]
# How to plot the evolution on time of HOIs

# %%
combos=model.get_combinations(minsize=minsize, maxsize=maxsize)[0]
list_indices=[[int(c) for c in comb if c != -1] for comb in combos]
list_multiplets=[str([int(i) for i in comb]) for comb in list_indices]


plt.figure(figsize=(4,4))
for i in range(len(oinfo[:,0])):
    if len(list_indices[i])==4:
        c='red'
        plt.hist(oinfo[i,:], label=list_multiplets[i], color='lightpink')
        plt.axvline(np.mean(oinfo[i,:]), color=c)
    else:
        c='gray'
        plt.hist(oinfo[i,:], label=list_multiplets[i])
        plt.axvline(np.mean(oinfo[i,:]), color=c)
plt.xlabel('oinfo')
#plt.legend()
plt.show()
plt.close()
# Out:
# Get list of multiplets

# %% [markdown]
# # Very significant

# %%
#the target variable can be multivariate
target = random.multivariate_normal([0,0],[[1,0],[0,1]], 300).T
n_samples = 4000
n_features = 4

data = np.zeros((n_features, n_samples))

data[0] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[1] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[2] =  random.normal(loc=0.0, scale=1.0, size=n_samples)

data[3]=data[2]+data[1]+data[0]+ 0.73*random.normal(loc=0.0, scale=1.0, size=n_samples)

data_boot=bootstrap(data.T)

# %%
# Here we define min and max order that we want to compute

minsize=2
maxsize=4

#Here we create a 
model = hoi.metrics.Oinfo(data_boot)
oinfo = model.fit(minsize=minsize, maxsize=maxsize)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]

# %%
combos=model.get_combinations(minsize=minsize, maxsize=maxsize)[0]
list_indices=[[int(c) for c in comb if c != -1] for comb in combos]
list_multiplets=[str([int(i) for i in comb]) for comb in list_indices]


plt.figure(figsize=(4,4))
for i in range(len(oinfo[:,0])):
    if len(list_indices[i])==4:
        c='red'
        plt.hist(oinfo[i,:], label=list_multiplets[i], color='lightpink')
        plt.axvline(np.mean(oinfo[i,:]), color=c)
    else:
        c='gray'
        plt.hist(oinfo[i,:], label=list_multiplets[i])
        plt.axvline(np.mean(oinfo[i,:]), color=c)
plt.xlabel('oinfo')
plt.legend()
plt.show()
plt.close()
# Out:
# Get list of multiplets

# %% [markdown]
# # Not significant

# %%
#the target variable can be multivariate
target = random.multivariate_normal([0,0],[[1,0],[0,1]], 300).T
n_samples = 4000
n_features = 4

data = np.zeros((n_features, n_samples))

data[0] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[1] =  random.normal(loc=0.0, scale=1.0, size=n_samples)
data[2] =  random.normal(loc=0.0, scale=1.0, size=n_samples)

data[3]=data[2]+data[1]+0.08*data[0]+ 0.43*random.normal(loc=0.0, scale=1.0, size=n_samples)

data_boot=bootstrap(data.T)

# %%
# Here we define min and max order that we want to compute

minsize=2
maxsize=4

#Here we create a 
model = hoi.metrics.Oinfo(data_boot)
oinfo = model.fit(minsize=minsize, maxsize=maxsize)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]

# %%
combos=model.get_combinations(minsize=minsize, maxsize=maxsize)[0]
list_indices=[[int(c) for c in comb if c != -1] for comb in combos]
list_multiplets=[str([int(i) for i in comb]) for comb in list_indices]


plt.figure(figsize=(4,4))
for i in range(len(oinfo[:,0])):
    if len(list_indices[i])==4:
        c='red'
        plt.hist(oinfo[i,:], label=list_multiplets[i], color='lightpink')
        plt.axvline(np.mean(oinfo[i,:]), color=c)
    else:
        c='gray'
        plt.hist(oinfo[i,:], label=list_multiplets[i])
        plt.axvline(np.mean(oinfo[i,:]), color=c)
plt.xlabel('oinfo')
plt.legend()
plt.show()
plt.close()
# Out:
# Get list of multiplets

# %%
combos=model.get_combinations(minsize=minsize, maxsize=maxsize)[0]
list_indices=[[int(c) for c in comb if c != -1] for comb in combos]
list_multiplets=[str([int(i) for i in comb]) for comb in list_indices]


plt.figure(figsize=(4,4))
for i in range(len(oinfo[:,0])):
    if len(list_indices[i])==4:
        c='red'
        plt.hist(oinfo[i,:], label=list_multiplets[i], color='lightpink')
        plt.axvline(np.mean(oinfo[i,:]), color=c)
    else:
        c='gray'
        plt.hist(oinfo[i,:], label=list_multiplets[i])
        plt.axvline(np.mean(oinfo[i,:]), color=c)
plt.xlabel('oinfo')
plt.xlim((-1,-0.75))
#plt.legend()
plt.show()
plt.close()
# Out:
# Get list of multiplets

# %% [markdown]
# ## higher-order spreading ?
#
# It is possible to notice in this simple scenario that we can measure a strong value of O information (or gradient of O information between features and target O(target, features) - O(features) ) between n variables, also when one of this variable is independent from the others. For example we observe a strong synergy between variables (0,1,2,3,4), even if we know that 3 and 4 are statistically independent from the rest.
#
# ## A better formulation of the problem, using the O-information
#
# It is simple to prove that if avariable $X_i$ is independent from the others we have: $\Omega(X_1, ..., X_{i-1}, X_i) = \Omega(X_1, ..., X_{i-1})$. Now, if the variable {$X_1, ..., X_{i-1}$} are presenting a strong synergistic/redundant O-information, when we study {$X_1, ..., X_{i-1}, X_i$}, we will observe the same value of synergistic/redudant O-information. To not consider the fact that the submultiplet {$X_1, ..., X_{i-1}$} is explaining the O information of the multiplet {$X_1, ..., X_{i-1}, X_i$} may lead to think that there is some synergy among all the variables of the multiplet, that is not the case.
#
# ## A possible way out
#
# A possible way to a (possibly) more accurate formulation is the following: if we want to know that the synergy/redundancy of the multiplets {$X_1, ..., X_{i-1}, X_i$} is involving all the variables, i.e. it is not due to a submultiplets effect, we have to check that, if we exclude from the computation of O information $X_i$, we have the same effect (decrease of synergy/redundancy) as when excluding all the other variable $X_j, j\in\{1,2, ...,n\}$.
#
# For the following part we will consider:
# $ X^n = \{X_1, ..., X_{i-1}, X_{i},..., X_n\}$ and $ X^n_{-i} = \{X_1, ...,  X_{i-1}, X_{i+1}, ..., X_n\}$
#
# In formulas we want to check that for each i, $\Omega(X^n)-\Omega(X^n_{-i}) <0 $ in the case of synergy, $>0$ in the case of redundancy. Then, if we are interested in the value of the genuine O information (i.e. not due to submultiplet), we can consider taking:
#
# $$sign(\Omega(X^n)-\Omega(X^n_{-i}))*min_i(|\Omega(X^n)-\Omega(X^n_{-i})|) \ \ \ \ if \ \ \  \ |\sum_i^n sign(\Omega(X^n)-\Omega(X^n_{-i}))| = n$$
#
# Another possibilities should be:
#
# $$sign(\Omega(X^n)-\Omega(X^n_{-i})) * \prod_i(|\Omega(X^n)-\Omega(X^n_{-i})|) \ \ \ \ if \ \ \ \ |\sum_i^n sign(\Omega(X^n)-\Omega(X^n_{-i}))| = n$$
#
# Where  $ X^n = \{X_1, ..., X_{i-1}, X_{i},..., X_n\}$ and $ X^n_{-i} = \{X_1, ...,  X_{i-1}, X_{i+1}, ..., X_n\}$
#
# For the product, there is the problem that is vanishing ...
#
# All of this can be generalised to the gradient of O information, as used in the toolbox to investigate the relationship between features and target.

# %%
combos=model.get_combinations(minsize=minsize, maxsize=maxsize)[0]
list_indices=[[int(c) for c in comb if c != -1] for comb in combos]
list_multiplets=[str([int(i) for i in comb]) for comb in list_indices]

#Here we use the function defined in utils to "clean" the higher-order spreading
goinfo_proc=oinfo_min(goinfo, list_indices, minsize=2)
vmin, vmax = -0.5,0.5

plt.figure(figsize=(5,10))
index=np.where(np.sum(np.abs(goinfo_proc), axis=1)>0.5)[0]
plt.pcolormesh(
    variables, np.array(list_multiplets)[index], goinfo_proc[index, :], cmap='RdBu_r', vmin=vmin, vmax=vmax
)

plt.colorbar()
plt.xlabel('Times')
plt.show()
plt.close()
# Out:
# Get list of multiplets

# %% [markdown]
# ## Statistics, permutation test
#
# To simulate the same situation as in the real scenario, we simulate the data of different subjects and perform our statistical pipeline.

# %% [markdown]
# True values of Oinfo

# %%
goinfo=goinfo_create_fit(data_features, target.T, minsize=minsize, maxsize=maxsize)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]

# %%
n_perm=500

parallel, p_fun = parallel_func(goinfo_create_fit, n_jobs=-1, total=n_perm)

perm = parallel(p_fun(data_features, np.random.permutation(target.T), minsize=minsize, maxsize=maxsize) for n_p in range(n_perm))

perm=np.array(perm)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]
#   0%|          |  : 0/500 [00:00<?,       ?it/s]
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# 100%|██████████| Oinfo (4):  3/3 [00:09<00:00,    3.21s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# 100%|██████████| Oinfo (4):  3/3 [00:09<00:00,    3.24s/it]Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.04it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.75it/s]    Copnorm data
#     Copnorm data
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.81it/s]Get list of multiplets
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.40it/s]Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:01<00:00,    1.28it/s]    Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:01<00:00,    1.33it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.39s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.22s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.03s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.77it/s]    Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.69s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.59s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.58s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.38s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.22it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.14it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.33s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.42it/s]Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.55it/s]    Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.44it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.04s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:02<00:04,    2.15s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.95s/it]Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.64s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.57s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.30s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.08it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.85s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.12it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.48it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.56s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.32s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.33s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.61s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.12it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.18it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.30s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.48s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.34s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.16it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.53s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.30s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.42s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.09it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.35s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.32it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.64it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.60s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.52s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
#                                                                Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.37it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.23it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.83s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.70s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.50it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.57s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.00s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.47s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.46s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:04<00:02,    2.51s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.05s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.23s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.19s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.47s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.14it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.67s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.77s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.61s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.62s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:07<00:03,    3.94s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.08it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.60s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.53s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.44s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.01s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.01it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.24it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.55s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.65s/it]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.74s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.78s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.49s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.53s/it]Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.14it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.00s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.57s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.83s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.66s/it]Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.69s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
# ...
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.76s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.11s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.36s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:02<00:04,    2.15s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.78s/it]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.94s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:07<00:03,    3.70s/it]Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.63s/it]/home/INT/neri.m/py410/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.56s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.22s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.76it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.52it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.48it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:00<00:01,    1.50it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.22s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.24s/it]    Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.09s/it]    Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:01<00:00,    1.84it/s]Get list of multiplets
# Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.67s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:04<00:02,    2.21s/it]    Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:02<00:04,    2.48s/it]    Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.18s/it]Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.45s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# 100%|██████████| Oinfo (4):  3/3 [00:07<00:00,    2.66s/it]    Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:04<00:02,    2.29s/it]Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.37s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.73s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:06<00:03,    3.55s/it]    Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:08<00:04,    4.40s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.28s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:02,    2.02s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:06<00:03,    3.35s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:04<00:02,    2.03s/it]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:02,    1.17s/it]    Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#  33%|███▎      | Oinfo (2):  1/3 [00:01<00:03,    1.70s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.56s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.67s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:03<00:01,    1.56s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#  67%|██████▋   | Oinfo (3):  2/3 [00:05<00:02,    2.98s/it]Get list of multiplets
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets

# %% [markdown]
# # creating the list for the permutation statistical test
#
#  effect : list
#     True effect list of length (n_roi,) composed of arrays each one of
#     shape (n_subjects, ..., n_times). Number of subjects per ROI could
#     be different
#
# perms : list
#     Permutation list of length (n_roi,) composed of arrays each one of
#     shape (n_perm, n_subjects, ..., n_times). Number of subjects per
#     ROI could be different
#
# inference : {'ffx', 'irfx'}
#     Perform either Fixed-effect ('ffx') or Random-effect ('rfx')
#     inferences. By default, random-effect is used
#
# mcp : {'cluster', 'maxstat', 'fdr', 'bonferroni', 'nostat', None}
#     Method to use for correcting p-values for the multiple comparison
#     problem. Use either :

# %%
effect_list=[goinfo[np.newaxis, i,:] for i in range(len(goinfo[:,0]))]
perm_list=[perm[:,np.newaxis, i,:] for i in range(len(goinfo[:,0]))]

# %%
from frites.workflow import WfStats

# %%
inference='ffx'
mcp='cluster'

wf = WfStats()
pv, tv = wf.fit(effect_list, perm_list, inference=inference, mcp=mcp, tail=0)
# Mean II across subjects
# Out:
# Definition of a non-parametric statistical workflow
#     Fixed-effect inference (FFX)
#     Cluster forming threshold (tail=0; alpha=0.05; tfce=None)
#     Inference at cluster-level
#     Cluster detection (threshold=0.0048465728759765625; tail=0)

# %%
p_values1=np.where(pv.T<0.003,1,0)

plt.figure(figsize=(5,50))
index=np.where(np.sum(np.abs(goinfo*p_values1), axis=1)>0)[0]
plt.pcolormesh(
    variables, np.array(list_multiplets)[index], goinfo[index, :], cmap='RdBu_r', vmin=vmin, vmax=vmax
)

plt.colorbar()
plt.xlabel('Times')
plt.show()
plt.close()

# %%
len(index)
# Out:
# 0

# %%
n_perm=500

goinfo=goinfo_create_fit_correction(data_features, target.T, minsize=minsize, maxsize=maxsize)

parallel, p_fun = parallel_func(goinfo_create_fit_correction, n_jobs=-1, total=n_perm)

perm = parallel(p_fun(data_features, np.random.permutation(target.T), minsize=minsize, maxsize=maxsize) for n_p in range(n_perm))

perm=np.array(perm)
# Out:
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]
# Get list of multiplets
#   0%|          |  : 0/500 [00:00<?,       ?it/s]
#     Copnorm data
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
#     Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
# Get list of multiplets
# Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]    Copnorm data
# Get list of multiplets
#     Copnorm data
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#   0%|          |  0/3 [00:00<?,       ?it/s]Get list of multiplets
#  67%|██████▋   | Oinfo (3):  2/3 [00:02<00:01,    1.51s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/INT/neri.m/code/acrho/notebooks/multivariate_gaussian.ipynb Cell 19 line 7
#       <a href='vscode-notebook-cell:/home/INT/neri.m/code/acrho/notebooks/multivariate_gaussian.ipynb#X30sZmlsZQ%3D%3D?line=2'>3</a> goinfo=goinfo_create_fit_correction(data_features, target.T, minsize=minsize, maxsize=maxsize)
#       <a href='vscode-notebook-cell:/home/INT/neri.m/code/acrho/notebooks/multivariate_gaussian.ipynb#X30sZmlsZQ%3D%3D?line=4'>5</a> parallel, p_fun = parallel_func(goinfo_create_fit_correction, n_jobs=-1, total=n_perm)
# ----> <a href='vscode-notebook-cell:/home/INT/neri.m/code/acrho/notebooks/multivariate_gaussian.ipynb#X30sZmlsZQ%3D%3D?line=6'>7</a> perm = parallel(p_fun(data_features, np.random.permutation(target.T), minsize=minsize, maxsize=maxsize) for n_p in range(n_perm))
#       <a href='vscode-notebook-cell:/home/INT/neri.m/code/acrho/notebooks/multivariate_gaussian.ipynb#X30sZmlsZQ%3D%3D?line=8'>9</a> perm=np.array(perm)
#
# File ~/code/frites/frites/utils/parallel.py:63, in parallel_func.<locals>.parallel_progress(op_iter)
#      62 def parallel_progress(op_iter):
# ---> 63     return parallel(ProgressBar(iterable=op_iter, max_value=total,
#      64                                 mesg=mesg))
#
# File ~/py410/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/py410/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/py410/lib/python3.11/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
effect_list=[goinfo_correct[np.newaxis, i,:] for i in range(len(goinfo[:,0]))]
perm_list=[perm[:,np.newaxis, i,:] for i in range(len(goinfo[:,0]))]

# %%
from frites.workflow import WfStats

# %%
inference='ffx'
mcp='cluster'

wf = WfStats()
pv, tv = wf.fit(effect_list, perm_list, inference=inference, mcp=mcp, tail=0)
# Mean II across subjects
# Out:
# Definition of a non-parametric statistical workflow
#     Fixed-effect inference (FFX)
#     Cluster forming threshold (tail=0; alpha=0.05; tfce=None)
#     Inference at cluster-level
#     Cluster detection (threshold=0.0006542205810546875; tail=0)

# %%
p_values1=np.where(pv.T<0.05,1,0)

plt.figure(figsize=(5,10))
index=np.where(np.sum(np.abs(goinfo_correct*p_values1), axis=1)>0)[0]
plt.pcolormesh(
    variables, np.array(list_multiplets)[index], goinfo_correct[index, :], cmap='RdBu_r', vmin=vmin, vmax=vmax
)

plt.colorbar()
plt.xlabel('Times')
plt.show()
plt.close()
