# %%
import numpy as np
import os.path as op

# %%
dir = '/home/INT/brovelli.a/code/acrho/data/spiking_model/project/spatial/homog'
for stim_type in range(2):

    for trial in range(20):

        fname = op.join(dir, "data/{0}_{1}signal.npy".format(stim_type, trial))
        field_model = np.load(fname)

# %%
plt.imshow(field_model[:,:], aspect='auto')
plt.show()
